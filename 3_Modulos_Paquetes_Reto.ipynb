# %% [markdown]
# # 🎓 Taller Práctico: Arquitectura de Software Modular
#
# **Objetivo:** En este taller no solo ejecutaremos código, **tú lo construirás**. Aprenderás a refactorizar funciones sueltas para convertirlas en un paquete profesional de Python.
#
# ---

# %% [markdown]
# ## 1. Preparación del Entorno
# Primero, vamos a preparar la carpeta donde vivirá nuestro paquete. En Python, la estructura de carpetas define el paquete.

# %%
import os

# Nombre del paquete
PAQUETE = "analisis_datos"

# Validamos si existe, si no, la creamos
if not os.path.exists(PAQUETE):
    os.makedirs(PAQUETE)
    print(f"✅ Carpeta '{PAQUETE}' creada.")
else:
    print(f"ℹ️ La carpeta '{PAQUETE}' ya existe, podemos continuar.")
# Out:
# ✅ Carpeta 'analisis_datos' creada.

# %% [markdown]
# ---
# ## 2. Módulo de Estadísticas (Lógica Pura)
#
# El primer archivo será `estadisticas.py`.
#
# **Tu misión:** Completar las funciones `media` y `mediana`.
# * Debes usar **Type Hinting** (pistas de tipo) para indicar qué entra y qué sale.
# * Debes manejar errores (por ejemplo, ¿qué pasa si la lista está vacía?).

# %%
# %%writefile analisis_datos/estadisticas.py
from typing import List, Union

# --- RETO 1: Completa la función media ---
def media(datos: List[Union[int, float]]) -> float:
    """
    Calcula el promedio de una lista de números.
    Debe lanzar un ValueError si la lista está vacía.
    """
    # 1. Valida si la lista 'datos' está vacía. Si sí, lanza ValueError.
    # TU CÓDIGO AQUÍ
    if not datos:
        raise ValueError('La lista de datos no puede estar vacía para calcular el promedio')
        
    # 2. Retorna la suma dividida por la cantidad de elementos
    # TU CÓDIGO AQUÍ
    promedios = sum(datos) / len(datos) 
    return promedios
    
    

# --- RETO 2: Completa la función mediana ---
def mediana(datos: List[Union[int, float]]) -> Union[int, float]:
    """
    Calcula el valor central de los datos.
    """
    if not datos:
        raise ValueError("Lista vacía")

    # 1. Ordena los datos (¡OJO! usa sorted() para no modificar la lista original)
    # TU CÓDIGO AQUÍ
    datos_sorted = sorted(datos)
    n = len(datos)
    mitad = n // 2

    # 2. Si n es par, devuelve el promedio de los dos del centro
    # 3. Si n es impar, devuelve el elemento central
    if n % 2 == 0:
        # TU CÓDIGO AQUÍ
        return (datos_sorted[mitad - 1] + datos_sorted[mitad]) / 2
    else:
        # TU CÓDIGO AQUÍ
        return datos_sorted[mitad]
# Out:
# Writing analisis_datos/estadisticas.py

# %% [markdown]
# ### 🔍 Validación (Test Unitario)
# Ejecuta la siguiente celda para verificar si tu código en `estadisticas.py` funciona correctamente. **Si falla, debes corregir el archivo de arriba y volver a ejecutarlo.**

# %%
try:
    from analisis_datos.estadisticas import media, mediana
    import importlib
    import analisis_datos.estadisticas
    importlib.reload(analisis_datos.estadisticas) # Recargamos por si hiciste cambios

    # Pruebas básicas
    lista_par = [1, 2, 3, 4]
    lista_impar = [1, 2, 3]
    
    print("Probando media... ", end="")
    assert media(lista_par) == 2.5, f"Error: Esperaba 2.5, obtuve {media(lista_par)}"
    print("✅ Correcto")

    print("Probando mediana (impar)... ", end="")
    assert mediana(lista_impar) == 2, f"Error: Esperaba 2, obtuve {mediana(lista_impar)}"
    print("✅ Correcto")

    print("Probando mediana (par)... ", end="")
    assert mediana(lista_par) == 2.5, f"Error: Esperaba 2.5, obtuve {mediana(lista_par)}"
    print("✅ Correcto")
    
except ImportError:
    print("❌ Error: No se pudo importar el módulo. ¿Ejecutaste la celda anterior?")
except AssertionError as e:
    print(f"❌ Falló la prueba: {e}")
except Exception as e:
    print(f"❌ Error en tu código: {e}")
# Out:
# Probando media... ✅ Correcto
# Probando mediana (impar)... ✅ Correcto
# Probando mediana (par)... ✅ Correcto

# %% [markdown]
# ---
# ## 3. Módulo de Carga de Datos (Entrada/Salida)
#
# Ahora crearemos `carga_datos.py`. Este módulo simula una base de datos de productos.
#
# **Tu misión:**
# 1. Usar la librería `random` para seleccionar productos.
# 2. Implementar `guardar_lista_compras` utilizando **Context Managers** (`with open...`) para asegurar que el archivo se cierre correctamente.

# %%
# %%writefile analisis_datos/carga_datos.py
import random
from typing import List, Tuple, Dict

def generar_lista_compras(cantidad: int = 5) -> List[Tuple[str, int]]:
    productos = {
        "manzanas": 1000, "bananos": 150, "cerezas": 2000, 
        "naranjas": 900, "pan": 2275, "leche": 840, 
        "huevos": 3400, "queso": 5000, 'arroz':2500, 'frijoles':1200
    }
    # RETO 3: Selecciona 'cantidad' productos aleatorios de la lista de items
    # Pista: Usa random.sample()
    # TU CÓDIGO AQUÍ
    cantidad = min(cantidad, len(productos))
    return random.sample((list(productos.items)),k=cantidad)


def guardar_lista_compras(lista_compras: List[Tuple[str, int]], nombre_archivo: str):
    """
    Guarda la lista en un archivo de texto.
    Formato: producto:precio
    """
    try:
        # RETO 4: Usa 'with open(...)' para abrir el archivo en modo escritura ('w')
        # Itera sobre la lista y escribe cada línea.
        # TU CÓDIGO AQUÍ
        with open(nombre_archivo,'W',encoding='utf-8') as archivo:
            for producto, precio in lista_compras:
                archivo.write(f"{producto}:{precio} \n")
        print(f'Archivo {nombre_archivo} guardado exitosamente!')

        print(f"✅ Archivo guardado en {nombre_archivo}")
    except Exception as e:
        print(f"❌ Error al guardar: {e}")
# Out:
# Writing analisis_datos/carga_datos.py

# %% [markdown]
# ### 🔍 Validación de Carga de Datos
# Vamos a probar si tu función genera la lista y si crea el archivo físico.

# %%
import os
from analisis_datos.carga_datos import generar_lista_compras, guardar_lista_compras

# Prueba 1: Generación
lista = generar_lista_compras(3)
if len(lista) == 3 and isinstance(lista, list):
    print("✅ generar_lista_compras funciona correctamente.")
else:
    print("❌ generar_lista_compras falló o devolvió datos incorrectos.")

# Prueba 2: Guardado
test_file = "test_lista.txt"
guardar_lista_compras(lista, test_file)

if os.path.exists(test_file):
    print("✅ El archivo fue creado exitosamente.")
    # Limpieza
    os.remove(test_file)
else:
    print("❌ El archivo NO fue creado. Revisa tu bloque 'with open'.")
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[5], line 2
#     from analisis_datos.carga_datos import generar_lista_compras, guardar_lista_compras
#
#   File c:\Users\Joss\Documents\GitHub\Taller_Arquitectura_Python_Modular_2025C3-G02\analisis_datos\carga_datos.py:31
#     print(f"✅ Archivo guardado en {nombre_archivo}")
#                                                     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# ---
# ## 4. El archivo `__init__.py` (La Fachada)
#
# Para que nuestro paquete sea fácil de usar, debemos exponer las funciones en el archivo `__init__.py`. Esto permite que el usuario haga `from analisis_datos import media` en lugar de `from analisis_datos.estadisticas import media`.
#
# **Tu misión:** Importa las funciones de los módulos locales (`.estadisticas` y `.carga_datos`) y defínelas en `__all__`.

# %%
# %%writefile analisis_datos/__init__.py
"""
Inicializador del paquete analisis_datos.
"""
#Apunta hacia los modulos, es como un link virtual para esos modulos
# RETO 5: Importa 'media' y 'mediana' desde .estadisticas
# TU CÓDIGO AQUÍ
from .estadisticas import media, mediana 

# RETO 6: Importa 'generar_lista_compras' y 'guardar_lista_compras' desde .carga_datos
from .carga_datos import generar_lista_compras, guardar_lista_compras

# Define la lista __all__ para exportar explícitamente
__all__ = ['media', 'mediana', 'generar_lista_compras', 'guardar_lista_compras']
# Out:
# Writing analisis_datos/__init__.py

# %% [markdown]
# ## 5. Integración Final
#
# Si has llegado hasta aquí, ¡felicidades! Has creado un paquete completo. Ejecuta la siguiente celda para ver todo tu trabajo en acción. Si algo falla, lee el error y regresa al módulo correspondiente para corregirlo.

# %%
try:
    # Reiniciamos el entorno de importación para asegurar que lea los últimos cambios
    import sys
    if 'analisis_datos' in sys.modules:
        del sys.modules['analisis_datos']
    
    from analisis_datos import * 
    #from analisis_datos import generar_lista_compras, guardar_lista_compras, media, mediana

    print("🛒 Generando compras...")
    cantidad = int(input('Ingrese la cantidad de productos que quiere comprar?'))
    mi_compra = generar_lista_compras(5)
    print(f"   Items: {mi_compra}")
    
    print("💾 Guardando ticket...")
    guardar_lista_compras(mi_compra, "ticket_final.txt")
    
    precios = [p for _, p in mi_compra]
    print(f"📊 Estadísticas del gasto:")
    print(f"   - Promedio: ¢{media(precios):.2f}")
    print(f"   - Mediana:  ¢{mediana(precios):.2f}")
    
    print("\n✨ ¡EXCELENTE TRABAJO! Has completado la refactorización.")
    
except ImportError as e:
    print(f"❌ Error de Importación: {e}. Revisa tu __init__.py")
except Exception as e:
    print(f"❌ Algo salió mal: {e}")
# Out:
# ❌ Algo salió mal: unindent does not match any outer indentation level (carga_datos.py, line 31)
